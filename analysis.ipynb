# %%
import pandas as pd
import glob
import numpy as np
import altair as alt
import json
import math
import matplotlib as mpp
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn import metrics
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 40)
filename = "processed/quantleague.csv"
quantleague = pd.read_csv(filename, index_col=None)
quantleague.drop(labels='Year.1', axis=1, inplace=True)
defaultxcols = ['gamelength', 'earlygoldblue', 'midgoldblue', 'earlygoldred', 'midgoldred',
                'earlygolddiff', 'midgolddiff',
                 'bDragons', 'bBarons', 'bHeralds',
                 'rDragons', 'rBarons', 'rHeralds', 'Year']
defaultycols = ['bluewin']

# %%
def createDataset(xcols, ycols, df):
    x = df[xcols]
    # #leaving out late gold columns
    y = df[ycols].to_numpy()
    x = StandardScaler().fit_transform(x)
    return train_test_split(x, y, train_size=.8, random_state=42)

# %%
x_train, x_test, y_train, y_test  = createDataset(defaultxcols, defaultycols, quantleague)

# %%
def visualizePCA(x_train, y_train, y_name):
    pca = PCA(n_components=2)
    principalcomponents = pca.fit_transform(x_train)
    pcs = pd.DataFrame(data=principalcomponents, columns=['PC1', 'PC2'])
    pcs[y_name] = y_train
    alt.Chart(pcs.sample(5000)).mark_point(size=1).encode(x='PC1', y='PC2', color=y_name).display()
    return pca

# %%
pca = visualizePCA(x_train, y_train, 'Blue win')
# Out:
# alt.Chart(...)

# %%
sum(pca.explained_variance_ratio_)
# This is great news! Around 63% of the variance of our data can be explained with just two principal components. Let's look at how many components we would need to capture
# 95% of the variance:
# Out:
# 0.5965303653796767

# %%
def visualizePCAComponents(x_train):
    numcomponents = x_train.shape[1]
    pca = PCA(numcomponents).fit(x_train)

    pca_variance = pd.DataFrame({
        'x': list(range(1,numcomponents+1)),
        'y': np.cumsum(pca.explained_variance_ratio_)
    })
    alt.Chart(pca_variance).mark_line().encode(
        x = alt.X('x', title='Number of components'),
        y = alt.Y('y', title='Cumulative explained variance', scale=alt.Scale(domain=(0.3,1.02)))
    ).interactive().display()

#To explain >=95% of variance, we need to use 11 components. We can see this means .... ?
 #First, we try creating a model to predict probability of winning based on early-mid game state, meaning we look at gold differences and neutral objectives taken.
  #Let's try doing a PCA to find which variables are most indicative of winning:

# %%
 visualizePCAComponents(x_train)
# Out:
# alt.Chart(...)

# %%
def LogReg(x_train, y_train):
    return LogisticRegression().fit(x_train, y_train)

def evaluateModel(model, x_test, y_test):    
    return model.score(x_test, y_test)

# %%
blueWinModel = LogReg(x_train, y_train)
evaluateModel(blueWinModel, x_test, y_test)
# Out:
# 0.8976377952755905

# %%
def confusion(model, x_test, y_test, labels):
    predictions = model.predict(x_test)
    return metrics.confusion_matrix(y_test, predictions, labels=labels, normalize='true')

def confusion_graph(confusion_matrix, labels):
    cmlen = confusion_matrix.shape[0]
    x,y = np.meshgrid(labels,labels)    
    source = pd.DataFrame({
        'x': x.ravel(),
        'y': y.ravel(),
        'z':confusion_matrix.ravel()
    })
    return alt.Chart(source).mark_rect().encode(
        x=alt.X('x:N', title="Predicted"),
        y=alt.Y('y:N', title="Target"),
        color='z:Q'
    ).properties(width=200, height=200)

# %%
confusion_graph(confusion(blueWinModel, x_test, y_test, np.unique(y_test)), np.unique(y_test))
# Out:
# alt.Chart(...)

# %%
def createCoeffs(labels, values, classes):   
    dat = {}    
    for i, k in enumerate(labels):
        dat[k] = []
        for j in values:            
            dat[k].append(j[i])        
    res= pd.DataFrame(dat, index=classes)
    if len(res) == 2:
        res.iloc[1, :] *= -1
    return res

# %%
def pipeline(xcols, ycols, df=quantleague):
    print('Creating data...')
    x_train, x_test, y_train, y_test = createDataset(xcols, ycols, df)
    print('Creating model...')
    model = LogReg(x_train, y_train)
    print('Evaluating model...')
    labels = np.unique(y_test)
    print('Accuracy:', evaluateModel(model, x_test, y_test))       
    # print('Coefficients:')
    # display(createCoeffs(xcols, model.coef_, labels))
    print('Displaying confusion matrix')    
    confusion_graph(confusion(model, x_test, y_test, labels), labels).display()

# %%
pipeline(defaultxcols, defaultycols)
# Out:
# Creating data...
# Creating model...
# Evaluating model...
# Accuracy: 0.8976377952755905
# Coefficients:
#    gamelength  earlygoldblue  midgoldblue  earlygoldred  midgoldred  \
# 0    0.456919      -0.003758    -0.064918      0.001802   -0.311468
# 1   -0.456919       0.003758     0.064918     -0.001802    0.311468
#
#    earlygolddiff  midgolddiff  bDragons   bBarons  bHeralds  rDragons  \
# 0      -0.020671     0.641232  0.649796  1.117982  0.038407 -0.633143
# 1       0.020671    -0.641232 -0.649796 -1.117982 -0.038407  0.633143
#
#     rBarons  rHeralds     Year
# 0 -1.254191 -0.037293  0.04978
# 1  1.254191  0.037293 -0.04978
# Displaying confusion matrix
# alt.Chart(...)

# %%
pipeline(['gamelength', 'totalgoldblue', 'earlygoldblue', 'midgoldblue',
       'lategoldblue', 'totalgoldred', 'earlygoldred', 'midgoldred',
       'lategoldred', 'earlygolddiff', 'midgolddiff', 'lategolddiff', 'bKills',
       'bTowers', 'bInhibs', 'bDragons', 'bBarons', 'bHeralds', 'rKills',
       'rTowers', 'rInhibs', 'rDragons', 'rBarons', 'rHeralds',
       'Year'], ['League'])
# Out:
# Creating data...
# Creating model...
# Evaluating model...
# Accuracy: 0.23818897637795275
# Coefficients:
#        gamelength  totalgoldblue  earlygoldblue  midgoldblue  lategoldblue  \
# CBLoL    1.308894      -0.562771      -0.140288    -0.666192      0.362281
# CLS      1.216116      -0.671462       0.376755    -0.572967     -0.217978
# EULCS   -0.392063      -0.057179       0.322316     0.792004     -0.873702
# IEM     -2.269956       0.881474       0.164386     0.237491      0.071637
# LCK     -0.656765       0.667265       0.012254    -0.272086      0.399066
# LCL      1.046148      -0.290534      -0.211982    -0.556120      0.820620
# LJL      2.304058      -1.131422      -0.036910    -0.632317      0.087880
# LLN      2.096365      -0.473241       0.038850    -0.516627      0.174163
# LMS      0.541480       0.103953       0.133614    -0.340922      0.298301
# MSI     -1.248514       0.578047      -0.261354     0.606516     -0.024745
# NALCS   -0.137325      -0.064495      -0.068864     0.629578     -0.441541
# OPL     -1.649994       0.295351       0.002626    -0.075525      0.204683
# RR      -0.229488       0.264296       0.015111     0.144307     -0.338478
# TCL      1.055991      -0.809600       0.211866     0.086207     -0.188958
# WC      -2.984946       1.270317      -0.558383     1.136654     -0.333229
#
#        totalgoldred  earlygoldred  midgoldred  lategoldred  earlygolddiff  \
# CBLoL      0.545013     -0.106997   -0.662660     0.354471      -0.116271
# OPL   -0.021681  0.067198  0.086047  0.237467 -0.123834 -0.183829  0.065018
# RR     0.331102  0.323146  0.581447  0.396236  0.268870  0.031484  0.035951
# TCL    0.221947  0.029547  0.542451  0.348670 -0.099855 -0.153011  0.288804
# WC     0.018438 -0.373534 -0.583989 -0.515139  0.009107 -0.338459  0.076033
#
#        rHeralds      Year
# CBLoL  0.265746  0.388343
# CLS    0.043642  1.618180
# EULCS -0.121166 -0.478568
# IEM   -0.216138 -1.176354
# LCK   -0.112670 -0.654086
# LCL    0.199978  0.259223
# LJL    0.255001  0.383089
# LLN   -0.113158  1.385222
# LMS   -0.175774 -0.407319
# MSI    0.174797 -0.536358
# NALCS -0.169365 -0.153136
# OPL   -0.007727 -0.005041
# RR     0.412353  1.225966
# TCL   -0.076543 -0.022563
# WC    -0.358976 -1.826598
# Displaying confusion matrix
# alt.Chart(...)

# %%
pipeline(['gamelength', 'totalgoldblue', 'earlygoldblue', 'midgoldblue',
       'lategoldblue', 'totalgoldred', 'earlygoldred', 'midgoldred',
       'lategoldred', 'earlygolddiff', 'midgolddiff', 'lategolddiff', 'bKills',
       'bTowers', 'bInhibs', 'bDragons', 'bBarons', 'bHeralds', 'rKills',
       'rTowers', 'rInhibs', 'rDragons', 'rBarons', 'rHeralds',
       'Year'], ['Season'])
# Out:
# Creating data...
# Creating model...
# Evaluating model...
# Accuracy: 0.5872703412073491
# Coefficients:
# gamelength
# totalgoldblue
# earlygoldblue
# midgoldblue
# lategoldblue
# totalgoldred
# earlygoldred
# midgoldred
# lategoldred
# earlygolddiff
# midgolddiff
# lategolddiff
# bKills
# bTowers
# bInhibs
# bDragons
# bBarons
# bHeralds
# rKills
# rTowers
# rInhibs
# rDragons
# rBarons
# rHeralds
# Year
# 2
# None
# Displaying confusion matrix
# alt.Chart(...)

# %%
pipeline(['gamelength', 'totalgoldblue', 'earlygoldblue', 'midgoldblue',
       'lategoldblue', 'totalgoldred', 'earlygoldred', 'midgoldred',
       'lategoldred', 'earlygolddiff', 'midgolddiff', 'lategolddiff', 'bKills',
       'bTowers', 'bInhibs', 'bDragons', 'bBarons', 'bHeralds', 'rKills',
       'rTowers', 'rInhibs', 'rDragons', 'rBarons', 'rHeralds',
       ], ['Year'])
# Out:
# Creating data...
# Creating model...
# Evaluating model...
# Accuracy: 0.7152230971128609
# Coefficients:
# gamelength
# totalgoldblue
# earlygoldblue
# midgoldblue
# lategoldblue
# totalgoldred
# earlygoldred
# midgoldred
# lategoldred
# earlygolddiff
# midgolddiff
# lategolddiff
# bKills
# bTowers
# bInhibs
# bDragons
# bBarons
# bHeralds
# rKills
# rTowers
# rInhibs
# rDragons
# rBarons
# rHeralds
# 5
# None
# Displaying confusion matrix
# alt.Chart(...)

# %%
pipeline(['gamelength', 'totalgoldblue', 'earlygoldblue', 'midgoldblue',
       'lategoldblue', 'totalgoldred', 'earlygoldred', 'midgoldred',
       'lategoldred', 'earlygolddiff', 'midgolddiff', 'lategolddiff', 'bKills',
       'bTowers', 'bInhibs', 'bDragons', 'bBarons', 'bHeralds', 'rKills',
# bHeralds      -0.032460
# rKills        -0.058557
# rTowers       -0.298247
# rInhibs        0.089057
# rDragons       0.160587
# rBarons       -0.063554
# rHeralds       0.023236
# Year          -0.636693
# Displaying confusion matrix
# alt.Chart(...)

# %%
#so it seems like league is very hard for the model to classify, as there are 14 classes and most of them don't have much data. Let's try comparing only the top 4 leagues that we have the most data for, in order to see if we can draw more meaningful conclusions. First we need to filter our dataset to only include these three leagues:
# lg. samples
# LCK 1445
# NALCS 1272
# EULCS 1099

def gL(name): #wrapper to select easier
    return quantleague['League'] == name

top4 = quantleague.loc[gL('NALCS') | gL('LCK') | gL('EULCS') | gL('LMS')]
top4.describe()
# Out:
#         gamelength  totalgoldblue  earlygoldblue   midgoldblue   lategoldblue  \
# count  4594.000000    4594.000000    4594.000000   4594.000000    4594.000000
# mean     37.492599   63438.196996    8416.601001  28478.826731   50690.442534
# std       7.959814   14836.535018    2072.981388   7070.004809   12150.388926
# min      19.000000   24947.000000    3701.000000  11449.000000   18859.000000
# 25%      32.000000   53450.000000    7069.250000  23561.500000   42227.500000
# 50%      36.000000   62041.000000    8147.000000  27526.500000   49169.500000
# 75%      42.000000   72089.750000    9500.750000  32274.250000   57255.250000
# max      95.000000  177698.000000   24252.000000  78494.000000  145273.000000
#
#         totalgoldred  earlygoldred    midgoldred    lategoldred  \
# count    4594.000000   4594.000000   4594.000000    4594.000000
# mean    62512.894645   8382.662386  28241.624946   50197.151720
# std     15689.561009   2066.126611   7159.366295   12628.680882
# min     24625.000000   3864.000000  12122.000000   20271.000000
# 25%     51342.000000   7002.000000  23301.750000   41252.500000
# 50%     61388.500000   8180.500000  27362.000000   49108.500000
# 75%     71721.000000   9478.000000  32099.750000   57247.500000
# max    173712.000000  24082.000000  90926.000000  141750.000000
#
#        earlygolddiff   midgolddiff  lategolddiff       bKills      bTowers  \
# count    4594.000000   4594.000000   4594.000000  4594.000000  4594.000000
# mean       33.927079    237.206356    493.277536    25.013931     6.766870
# std       566.144396   2733.882267   6649.187788    13.081608     3.596613
# min     -2464.000000 -12432.000000 -16736.000000     0.000000     0.000000
# 25%      -291.000000  -1674.500000  -5196.250000    14.000000     3.000000
# 50%        30.000000    234.000000   1131.500000    24.000000     8.000000
# 75%       346.500000   2124.000000   6069.750000    34.000000    10.000000
# max      2499.000000   9319.000000  17347.000000   112.000000    16.000000
#
#            bInhibs     bDragons      bBarons     bHeralds       rKills  \
# count  4594.000000  4594.000000  4594.000000  4594.000000  4594.000000
# mean      1.232042     1.914889     0.741620     0.304528    23.515020
# std       1.364430     1.380380     0.754449     0.532212    13.882398
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     1.000000     0.000000     0.000000    12.000000
# 50%       1.000000     2.000000     1.000000     0.000000    22.000000
# 75%       2.000000     3.000000     1.000000     1.000000    34.000000
# max      14.000000     8.000000     5.000000     3.000000    82.000000
#
#            rTowers      rInhibs     rDragons      rBarons     rHeralds  \
# count  4594.000000  4594.000000  4594.000000  4594.000000  4594.000000
# mean      5.949282     1.015455     1.935133     0.741620     0.228559
# std       3.750468     1.323053     1.460166     0.837077     0.478589
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       2.000000     0.000000     1.000000     0.000000     0.000000
# 50%       6.000000     1.000000     2.000000     1.000000     0.000000
# 75%      10.000000     2.000000     3.000000     1.000000     0.000000
# max      14.000000    14.000000     7.000000     6.000000     3.000000
#
#            bluewin         Year  League_CBLoL  League_CLS  League_EULCS  \
# count  4594.000000  4594.000000        4594.0      4594.0   4594.000000
# mean      0.543970  2016.194819           0.0         0.0      0.239225
# std       0.498117     0.869023           0.0         0.0      0.426657
# min       0.000000  2015.000000           0.0         0.0      0.000000
# 25%       0.000000  2015.000000           0.0         0.0      0.000000
# 50%       1.000000  2016.000000           0.0         0.0      0.000000
# 75%       1.000000  2017.000000           0.0         0.0      0.000000
# max       1.000000  2018.000000           0.0         0.0      1.000000
#
#        League_IEM   League_LCK  League_LCL  League_LJL  League_LLN  \
# count      4594.0  4594.000000      4594.0      4594.0      4594.0
# mean          0.0     0.314541         0.0         0.0         0.0
# std           0.0     0.464383         0.0         0.0         0.0
# min           0.0     0.000000         0.0         0.0         0.0
# 25%           0.0     0.000000         0.0         0.0         0.0
# 50%           0.0     0.000000         0.0         0.0         0.0
# 75%           0.0     1.000000         0.0         0.0         0.0
# max           0.0     1.000000         0.0         0.0         0.0
#
#         League_LMS  League_MSI  League_NALCS  League_OPL  League_RR  \
# count  4594.000000      4594.0   4594.000000      4594.0     4594.0
# mean      0.169351         0.0      0.276883         0.0        0.0
# std       0.375103         0.0      0.447507         0.0        0.0
# min       0.000000         0.0      0.000000         0.0        0.0
# 25%       0.000000         0.0      0.000000         0.0        0.0
# 50%       0.000000         0.0      0.000000         0.0        0.0
# 75%       0.000000         0.0      1.000000         0.0        0.0
# max       1.000000         0.0      1.000000         0.0        0.0
#
#        League_TCL  League_WC  Season_Spring  Season_Summer  \
# count      4594.0     4594.0    4594.000000    4594.000000
# mean          0.0        0.0       0.464954       0.535046
# std           0.0        0.0       0.498825       0.498825
# min           0.0        0.0       0.000000       0.000000
# 25%           0.0        0.0       0.000000       0.000000
# 50%           0.0        0.0       0.000000       1.000000
# 75%           0.0        0.0       1.000000       1.000000
# max           0.0        0.0       1.000000       1.000000
#
#        Type_International  Type_Playoffs  Type_Promotion  Type_Regional  \
# count              4594.0    4594.000000     4594.000000    4594.000000
# mean                  0.0       0.093165        0.085111       0.031128
# std                   0.0       0.290695        0.279077       0.173681
# min                   0.0       0.000000        0.000000       0.000000
# 25%                   0.0       0.000000        0.000000       0.000000
# 50%                   0.0       0.000000        0.000000       0.000000
# 75%                   0.0       0.000000        0.000000       0.000000
# max                   0.0       1.000000        1.000000       1.000000
#
#        Type_Season
# count  4594.000000
# mean      0.790596
# std       0.406927
# min       0.000000
# 25%       1.000000
# 50%       1.000000
# 75%       1.000000
# max       1.000000

# %%
def getNonLeague(l):
    res = []
    for x in l:
        if 'League' not in x:
            res.append(x)
    res.remove('Year')
    res.remove('Season')
    res.remove('Type')
    return res

pipeline(getNonLeague(list(top4.columns)), ['League'], df=top4)
# Out:
# Creating data...
# Creating model...
# Evaluating model...
# Accuracy: 0.381936887921654
# [[-2.58382616e-01 -1.29497360e-01  1.92088870e-01  6.23558450e-01
#   -7.33934002e-01 -1.68096932e-01  1.78438327e-01  6.17190118e-01
#   -6.67792391e-01  4.79415668e-02 -4.27111926e-03 -7.33174415e-02
#    1.29805559e-01  5.43607438e-01 -9.92288961e-02 -2.07905731e-01
